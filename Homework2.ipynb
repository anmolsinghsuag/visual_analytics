# %%
import numpy as np
from scipy import stats

#Using Bokeh 0.12.5 and Python 3.6
from bokeh.io import output_notebook, show
from bokeh.models import Select,CustomJS
from bokeh.layouts import row,column
from bokeh.plotting import figure, ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1ad5893a-0b60-4c71-aa79-db341c032149">Loading BokehJS ...</span>
#     </div>

# %%
#Loading files into Numpy arrays
#Missing values substituted by -1
data_original = np.genfromtxt('data/data_full.csv',delimiter=",",dtype=None,skip_header=1)
data_missing = np.genfromtxt('data/data_miss.csv',delimiter=",",dtype=None,skip_header=1)

#Finding Missing values and storing them in row_missing,col_missing arrays
row_missing=np.where(data_missing<0)[0]
col_missing=np.where(data_missing<0)[1]

#Subtracting the rows that have values missing
data_slice=np.delete(data_missing, row_missing, axis=0)
data_slice_missing=data_missing[row_missing,:]

# %%
#Estimating the value of missing data

#Approach 1: Using Mean,Median or Mode
#In this approach the mean,median and mode are calculated for the columns for which the data is missing.
#Note that data_slice doesn't have the rows that have any value missing

#Calculating Mean of an array column
def columnMean(array,col):
    return np.average(array[:,col])

#Calculating Median of an array column
def columnMedian(array,col):
    return np.median(array[:,col])

#Calculating Mode of an array column
def columnMode(array,col):
    return stats.mode(array[:,col])[0][0]

# %%
#Approach 2 : Using K-Nearest Neighbours

class KNN(object):
    def _init_(self):
        pass
    
    def train(self,train_matrix,train_values):
        #Just saves the values
        #train_matrix doesn't have column of the missing value, train_values is that column
    
        self.train_matrix=train_matrix
        self.train_values=train_values
        
    def predict(self,predict_row,k):
        
        #Takes only one row as input to predict the value of missing column
        #predict_row doesn't have the dimension of the missing column
        
        #Finding L2 Euclidean Distance between all rows of training set and broadcasted row whose missing value is needed
        dists=np.sqrt(np.sum(np.square(self.train_matrix-predict_row),axis=1))
        
        #Fetching the values of the k nearest neighbours corresponding to missing column
        closest_k=self.train_values[np.argsort(dists,kind='quicksort')[0:k]]
        
        #Taking the average of the values of nearest neighbours
        return np.average(closest_k)

# %%
def executeKNN(k,pred_row,pred_col):
    #X_train is the data matrix minus the row and column for which the data is missing
    #Y_train is the column for which the data is missing
    X_train=data_slice[:,[x for x in range(data_missing.shape[1]) if x!=pred_col]]
    Y_train=data_slice[:,pred_col]
    
    classifier=KNN()
    classifier.train(X_train,Y_train)
    
    pred_value=classifier.predict(data_missing[pred_row,[x for x in range(data_missing.shape[1]) if x!=pred_col]],k)
    return pred_value

# %%
#Creating datasets for plots, 1. Mean, 2. Median 3. Mode 4. 1-KNN 5.5-KNN 6. 10-KNN 7. 17-KNN 8. 20-KNN
mean_squared_errors=[]
calculated_data=[]
row_indices=[]
col_indices=[]

mean_squared_errors_dictionary={}
calculated_data_dictionary={}
row_indices_dictionary={}
col_indices_dictionary={}
x_data_dictionary={}

dictionary={}


def evaluate(col_no, estimation_type,k):
    row_nums=[]
    data_filled=data_missing;
    mean_squared=0.0
    
    for index, col in enumerate(col_missing):
        if(col==col_no):
            val=0.0
            row_no=row_missing[index]
            row_nums.append(row_no)
            if (estimation_type==1): #Mean
                val=columnMean(data_slice,col_no)
                data_filled[row_no,col_no]=val
            
            if (estimation_type==2): #Median
                val=columnMedian(data_slice,col_no)
                data_filled[row_no,col_no]=val
                #print(val)
            
            if (estimation_type==3): #Mode
                val=columnMode(data_slice,col_no)
                data_filled[row_no,col_no]=val
                #print(val)
            
            if (estimation_type==4): #KNN
                val=executeKNN(k,row_no,col_no)
                data_filled[row_no,col_no]=val
                #print(val)
                
            mean_squared=mean_squared+(data_original[row_no,col_no]-val)**2
            #print(mean_squared)
    
    
    dict_label='c'+str(col_no)+'t'+str(estimation_type)+'k'+str(k)
    
    y_axis=data_filled[:,col_no]
    calculated_data.append(np.array(y_axis))
    calculated_data_dictionary[dict_label]=np.array(y_axis)
    dictionary[dict_label+'y']=np.array(y_axis)
    
    mean_squared=mean_squared**(1/2.0)
    mean_squared_errors.append(np.array(mean_squared))
    dictionary[dict_label+'m']=np.array(mean_squared)
    
    
    
    row_indices.append(np.array(row_nums))
    row_indices_dictionary[dict_label]=np.array(row_nums)
    dictionary[dict_label+'r']=np.array(row_nums)
    
    col_indices.append(np.array(col_no))
    col_indices_dictionary[dict_label]=np.array(col_no)
    dictionary[dict_label+'c']=np.array(col_no)
    
    x_data_dictionary[dict_label]=data_original[:,col_no]
    dictionary[dict_label+'x']=np.array(data_original[:,col_no])
 
    

for x in np.unique(col_missing):
    evaluate(x,1,1)
    evaluate(x,2,1)
    evaluate(x,3,1)
    evaluate(x,4,1)
    evaluate(x,4,5)
    evaluate(x,4,10)
    evaluate(x,4,17)
    evaluate(x,4,20)

# %%
# Making scatter plots for original columns values vs predicted column values
#Interactions allowing user to choose the kind of estimation and column



menu=[]
menu.append(('0','Mean'))
menu.append(('1','Median'))
menu.append(('2','Mode'))
menu.append(('3','1-Nearest Neighbour'))
menu.append(('4','5-Nearest Neighbour'))
menu.append(('5','10-Nearest Neighbour'))
menu.append(('6','17-Nearest Neighbour'))
menu.append(('7','20-Nearest Neighbour'))

menu2=[]
menu2.append(('0','Milk'))
menu2.append(('1','Grocery'))
menu2.append(('2','Detergent'))
menu2.append(('3','Delicassen'))

#source=ColumnDataSource(data=dict(compType=[comp_type]))


#estimation_type_dd=Select(title="Choose Estimation type",value="0", options=menu)
#column_dd=Select(title="Choose Column",value="0", options=menu2)

#estimation_type_chosen=estimation_type_dd
#print(estimation_type_chosen.value)

comp_types=[0,1,2,3,6,8,9,10,11,14,16,17,18,19,22,24,25,26,27,30]
col_names=['Milk','Milk','Milk','Milk','Milk','Grocery','Grocery','Grocery','Grocery','Grocery','Detergents','Detergents','Detergents','Detergents','Detergents','Delicassen','Delicassen','Delicassen','Delicassen','Delicassen']
estimate_type=['Mean','Median','Mode','1-Nearest Neighbour','17-Nearest Neighbour','Mean','Median','Mode','1-Nearest Neighbour','17-Nearest Neighbour','Mean','Median','Mode','1-Nearest Neighbour','17-Nearest Neighbour','Mean','Median','Mode','1-Nearest Neighbour','17-Nearest Neighbour','Mean','Median','Mode','1-Nearest Neighbour','17-Nearest Neighbour']

figList=[]
counter=0
for comp_type in comp_types:
    figList.append(figure(plot_width=600, plot_height=350,x_range=(0, 9000), y_range=(0, 9000),title='Estimation Type:'+' '+str(estimate_type[counter])+'  '+'Column Name: '+str(col_names[counter])+'  '+'Mean Square Error:'+' '+ str(mean_squared_errors[comp_type])))
    figList[counter].circle(data_original[:,col_indices[comp_type]],calculated_data[comp_type], size=2, fill_color="blue", fill_alpha=0.5)
#Plotting  the curve
#fig =figure(plot_width=700, plot_height=450,x_range=(0, 5000), y_range=(0, 5000),title='Mean Square Error:'+ str(mean_squared_errors[comp_type]))
#sc1=fig.circle(data_original[:,col_indices[comp_type]],calculated_data[comp_type], size=2, fill_color="blue", fill_alpha=0.5)
    
#Highlighting the approximate values in yellow and actual values in red
#sc2=fig.circle(data_original[row_indices[comp_type],col_indices[comp_type]],calculated_data[comp_type][row_indices[comp_type]], size=10, fill_color="yellow",legend="Estimated Value")
#sc3=fig.circle(data_original[row_indices[comp_type],col_indices[comp_type]],data_original[row_indices[comp_type],col_indices[comp_type]], size=10, fill_color="red",legend="Actual Value")
    figList[counter].circle(data_original[row_indices[comp_type],col_indices[comp_type]],calculated_data[comp_type][row_indices[comp_type]], size=10, fill_color="yellow",legend="Estimated Value")
    figList[counter].circle(data_original[row_indices[comp_type],col_indices[comp_type]],data_original[row_indices[comp_type],col_indices[comp_type]], size=10, fill_color="red",legend="Actual Value")
    counter=counter+1


#estimation_type_dd.js_on_change('value', update_curve)
#column_dd.js_on_change('value', update_curve)

##show(row(fig,column(estimation_type_dd,column_dd)))

# %%
#Finding Best Estimation technique over all columns

tec_name=['Mean','Median','Mode','1-NN','5-NN','10-NN','17-NN','20-NN']
Mse_list=np.zeros(8)
colors=["#4B5C8A","red","blue","yellow","orange","magenta","firebrick","pink"]
Mse_list[0]=np.sum([mean_squared_errors[x] for x in [0,8,16,24]])
Mse_list[1]=np.sum([mean_squared_errors[x] for x in [1,9,17,25]])
Mse_list[2]=np.sum([mean_squared_errors[x] for x in [2,10,18,26]])
Mse_list[3]=np.sum([mean_squared_errors[x] for x in [3,11,19,27]])
Mse_list[4]=np.sum([mean_squared_errors[x] for x in [4,12,20,28]])
Mse_list[5]=np.sum([mean_squared_errors[x] for x in [5,13,21,29]])
Mse_list[6]=np.sum([mean_squared_errors[x] for x in [6,14,22,30]])
Mse_list[7]=np.sum([mean_squared_errors[x] for x in [7,15,23,31]])


p = figure(plot_width=900, plot_height=500,title="Mean Square Errors for different estimations")
for x in range(8):
    
    p.vbar(x=2*x, width=0.5, bottom=0,
    top=Mse_list[x], color=colors[x],legend=tec_name[x])
    
show(p)




#17 and 20 Nearest neighbour approaches seem to be working the best as the have least MSE
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b79217ee-463b-4785-aa40-59d6144c144c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b79217ee-463b-4785-aa40-59d6144c144c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b79217ee-463b-4785-aa40-59d6144c144c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b79217ee-463b-4785-aa40-59d6144c144c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bb2be7e4-4512-4efa-8f71-4d34036f218b":{"roots":{"references":[{"attributes":{"label":{"value":"17-NN"},"renderers":[{"id":"c5f95961-4115-4896-9b19-ded6ad643678","type":"GlyphRenderer"}]},"id":"711d6a6a-270e-4f97-a206-24cd95f4892e","type":"LegendItem"},{"attributes":{"data_source":{"id":"5cc2cf98-cd77-49d5-842b-a088a3991ac7","type":"ColumnDataSource"},"glyph":{"id":"5ec68e2b-6ab0-48a5-ac96-d830fc422147","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ea577690-70eb-4da4-9aba-6455b1d8460f","type":"VBar"},"selection_glyph":null},"id":"eefbe02c-28e0-44d9-977a-04227ca2707b","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"68627119-dfc4-47fe-a638-ddc0055ef4d7","type":"BasicTickFormatter"},"plot":{"id":"103ce6b6-9718-420c-90ec-ee218bca53cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"8030a836-6fc2-4932-9124-ba0d8f221680","type":"BasicTicker"}},"id":"d2c2f564-3e01-4fd1-a74d-01b821ee0159","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"pink"},"line_color":{"value":"pink"},"top":{"value":3625.4058574197047},"width":{"value":0.5},"x":{"value":14}},"id":"5ec68e2b-6ab0-48a5-ac96-d830fc422147","type":"VBar"},{"attributes":{"plot":{"id":"103ce6b6-9718-420c-90ec-ee218bca53cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"8030a836-6fc2-4932-9124-ba0d8f221680","type":"BasicTicker"}},"id":"b549963b-6328-4f3f-a4fc-2193c218a125","type":"Grid"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"top":{"value":7977.971611167931},"width":{"value":0.5},"x":{"value":2}},"id":"51e3da51-7f31-4dcd-a85b-a43731950f72","type":"VBar"},{"attributes":{"label":{"value":"Mean"},"renderers":[{"id":"3ab576a7-0608-46d6-ae57-f5dc0d7a5657","type":"GlyphRenderer"}]},"id":"d5e60dff-ca34-4966-b1cc-32cd173c3062","type":"LegendItem"},{"attributes":{"plot":{"id":"103ce6b6-9718-420c-90ec-ee218bca53cf","subtype":"Figure","type":"Plot"}},"id":"15b01e85-e092-46f5-82bf-485e36d960c9","type":"ResetTool"},{"attributes":{"data_source":{"id":"f1ae3ffb-a5cb-4923-b1e8-d637bb403ab5","type":"ColumnDataSource"},"glyph":{"id":"1b8b848c-adf7-46cc-86dd-cb1d57c1ebab","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9c769de1-bcfe-4417-bb4d-2cd19cbe72fd","type":"VBar"},"selection_glyph":null},"id":"3ab576a7-0608-46d6-ae57-f5dc0d7a5657","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"0d0fca0e-a04b-4344-a1e2-131b8b05c96f","type":"ColumnDataSource"},"glyph":{"id":"66b48e1d-1abc-4608-a6e6-60793329bc74","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f8fcd27a-e31f-4c75-81b8-1db58625fa1c","type":"VBar"},"selection_glyph":null},"id":"c6188255-5935-40c9-9ebc-157c9bed00d4","type":"GlyphRenderer"},{"attributes":{"callback":null,"data":{}},"id":"9314adc1-b28e-464d-a6f6-0bf63d48fa0b","type":"ColumnDataSource"},{"attributes":{},"id":"8030a836-6fc2-4932-9124-ba0d8f221680","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"103ce6b6-9718-420c-90ec-ee218bca53cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"cfab7946-e811-4561-aeea-8a0d2ad58bd0","type":"BasicTicker"}},"id":"ee62ce61-182d-42ee-9db8-fe2b9ef37cbe","type":"Grid"},{"attributes":{"callback":null,"data":{}},"id":"eac425ff-27c6-49e0-88da-4e65b1b3803d","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"cf4ea13b-c178-49d7-bb14-08a9bbc89581","type":"DataRange1d"},{"attributes":{},"id":"26d916b3-4789-4652-9b9a-ecaf1efdce83","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"103ce6b6-9718-420c-90ec-ee218bca53cf","subtype":"Figure","type":"Plot"}},"id":"c66aaab6-f98c-45e6-9733-ecdb990f9ded","type":"HelpTool"},{"attributes":{"data_source":{"id":"89a66aee-2c7b-42ef-8038-e4a8a1d1ce35","type":"ColumnDataSource"},"glyph":{"id":"79974eda-b71e-4ea9-b5db-34e1b686f6d8","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"25e857fc-0bff-41d5-befd-33661fe0c19a","type":"VBar"},"selection_glyph":null},"id":"c5f95961-411 ...

# %%
#Displaying the estimated values for column Milk
show(row(figList[:5]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6ffd9e75-b595-443d-ba9d-084075b5af45"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6ffd9e75-b595-443d-ba9d-084075b5af45");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6ffd9e75-b595-443d-ba9d-084075b5af45");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6ffd9e75-b595-443d-ba9d-084075b5af45' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8b8138aa-fd6c-463b-957f-fee6426f2712":{"roots":{"references":[{"attributes":{"plot":{"id":"8339674b-9047-4304-92b4-bda1686c8bd3","subtype":"Figure","type":"Plot"}},"id":"f267fa10-9090-4b76-a9d5-61fd5583cf29","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1e418ab8-d582-4574-9d30-908a91061ab5","type":"PanTool"},{"id":"7d4f7ff0-66f9-43ed-bda2-d17ba88e791a","type":"WheelZoomTool"},{"id":"2b1b4b0e-1c63-4dab-a0bd-4b74c0c349dc","type":"BoxZoomTool"},{"id":"4881453c-9d3f-4e06-a120-f06d779b56b1","type":"SaveTool"},{"id":"f8e72b7f-da52-4484-99c7-586854887ea1","type":"ResetTool"},{"id":"1a9046c7-5cd1-4616-9cf8-a8ed644e1729","type":"HelpTool"}]},"id":"46a81134-f696-42d2-af05-2cb7c62518ab","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"blue"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"fa2f9e06-7b36-40de-9701-91da84a27e32","type":"Circle"},{"attributes":{"data_source":{"id":"70c77182-1abc-41d8-998c-095001dc46c6","type":"ColumnDataSource"},"glyph":{"id":"fa2f9e06-7b36-40de-9701-91da84a27e32","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"4205f082-38ae-46c9-bf70-ee279d6933e1","type":"Circle"},"selection_glyph":null},"id":"b063fd3a-bc98-4e2d-b7f3-79da9665cdfa","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"8b55a3ea-8b4f-43b7-b7a7-f35cee005c00","type":"BasicTickFormatter"},"plot":{"id":"3023696e-4c9e-41cc-a613-bb60eb7dab03","subtype":"Figure","type":"Plot"},"ticker":{"id":"b22bf2fc-1bf1-4f5e-8970-7bbe5c1952e0","type":"BasicTicker"}},"id":"749db2d0-2573-416f-b718-a99efa1c3ccd","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"yellow"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c0a7d1b-17b1-4b8b-8146-01b8f8c05ad4","type":"Circle"},{"attributes":{"items":[{"id":"83d583b2-bb52-4a60-b116-04ce5427ac21","type":"LegendItem"},{"id":"3ca865e2-b050-4dc3-8344-045143766824","type":"LegendItem"}],"plot":{"id":"b3614efa-1663-44dc-a2fe-90e98b990334","subtype":"Figure","type":"Plot"}},"id":"cb77c1d5-e9e0-4ed0-a7ba-6a01acad8b0e","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bb828897-c619-4d9e-87c7-e4f666185fb6","type":"PanTool"},{"id":"b50edc1b-fa57-46ae-a896-597dcabffec9","type":"WheelZoomTool"},{"id":"5cf4a515-4059-44d1-b748-36f123754e1b","type":"BoxZoomTool"},{"id":"f267fa10-9090-4b76-a9d5-61fd5583cf29","type":"SaveTool"},{"id":"983dc5c3-dbd8-4657-99f4-c31aa28781f5","type":"ResetTool"},{"id":"18a7023e-c0ad-43ef-b60e-6f2ee1c2cd7a","type":"HelpTool"}]},"id":"ba1a30c6-588d-4a54-b3df-58ac1d029f7a","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a29e4ada-9647-497a-9dee-16ff3d0a7c65","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"7cd780a5-68d9-40dc-97a7-799cba30552c","type":"BasicTickFormatter"},"plot":{"id":"b3614efa-1663-44dc-a2fe-90e98b990334","subtype":"Figure","type":"Plot"},"ticker":{"id":"1ddf66b8-bb59-48f0-bea8-a576cfa5b06b","type":"BasicTicker"}},"id":"74d43738-5c96-4130-bbec-93378f5c8530","type":"LinearAxis"},{"attributes":{"label":{"value":"Actual Value"},"renderers":[{"id":"342f06e6-8763-40bf-8dfd-0708e8c83e13","type":"GlyphRenderer"}]},"id":"d5e4b086-6123-45a9-9ca9-ad66dfae0692","type":"LegendItem"},{"attributes":{},"id":"cdacc1fe-8fd6-4a41-b0a5-e7d85d95d610","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"fi ...

# %%
#Displaying the estimated values for column Grocery
show(row(figList[5:10]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2598ba78-3d3b-4186-af90-58a04ece12b6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2598ba78-3d3b-4186-af90-58a04ece12b6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2598ba78-3d3b-4186-af90-58a04ece12b6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2598ba78-3d3b-4186-af90-58a04ece12b6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"91c70f80-7a4e-493c-b634-19c3d94ec6e5":{"roots":{"references":[{"attributes":{"items":[{"id":"f7332b14-b512-4d7f-9a42-0e11a7c2e57f","type":"LegendItem"},{"id":"e9afb4bf-b047-48a3-819a-00f67f18a0da","type":"LegendItem"}],"plot":{"id":"55f65041-d3ae-4bc4-8e99-348f30f88398","subtype":"Figure","type":"Plot"}},"id":"858f00b9-bae2-42fd-96aa-e4df5ce33c40","type":"Legend"},{"attributes":{"label":{"value":"Actual Value"},"renderers":[{"id":"13ae8699-4ad3-42b5-be38-33a73f65d4d5","type":"GlyphRenderer"}]},"id":"c72b06bc-1fe8-47e4-a078-d79284611ed7","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3,6536],"y":[3,6536]}},"id":"353d7fcc-1a4f-4f93-80a1-332551a119ff","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3c11ea90-ab18-477a-83e9-c7f05fa2d203","type":"ColumnDataSource"},"glyph":{"id":"e6683285-4d58-48a2-ba3b-5ae7864faeb9","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2141e5c1-72bc-4d84-afda-d17988cd1ea9","type":"Circle"},"selection_glyph":null},"id":"13ae8699-4ad3-42b5-be38-33a73f65d4d5","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"00f4da33-1de5-4626-a407-29036081b438","subtype":"Figure","type":"Plot"}},"id":"4d037c5d-be12-47af-a560-f29f15396d46","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"127930b1-2b8f-46ba-ab7d-7aaa46fa930c","type":"Circle"},{"attributes":{},"id":"65f2d2e3-598d-4b7c-96a4-b160737e67c0","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"0e4b7b00-980e-42d5-a7d7-3f8f64e3c8f3","type":"ColumnDataSource"},"glyph":{"id":"51f95dc8-2d2d-49b5-9db6-ea8b02932bc7","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8c6af8ed-3826-441f-aee5-b80a9d3d1515","type":"Circle"},"selection_glyph":null},"id":"fe7a1b1a-8e60-408a-a925-07e4e0bbd227","type":"GlyphRenderer"},{"attributes":{},"id":"7e877e78-6db8-41e3-9931-dfc481d0e868","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e60f7c77-1b0a-4e2f-ac0f-291d564659e1","type":"BoxAnnotation"},{"attributes":{"label":{"value":"Estimated Value"},"renderers":[{"id":"d27fb39b-34c7-4ae9-8909-cc742ff8cabf","type":"GlyphRenderer"}]},"id":"a7fbe9d3-04d2-4b29-a05b-41bd2b249618","type":"LegendItem"},{"attributes":{},"id":"21a0f3a2-d3b8-457f-b3ce-6d71933c39a5","type":"BasicTicker"},{"attributes":{},"id":"ceac6e8f-05a6-4ca8-8b48-3e42b9951444","type":"BasicTicker"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"6569ef0a-4f7a-4d8d-8b3d-c1a85893df7d","type":"Circle"},{"attributes":{"callback":null,"end":9000},"id":"291d54e0-9ae9-4a6f-8fcf-bccbc3173e44","type":"Range1d"},{"attributes":{"label":{"value":"Estimated Value"},"renderers":[{"id":"b68da845-05de-4154-b5d1-8d5a2f59da57","type":"GlyphRenderer"}]},"id":"02ab2845-7d25-4dd0-8e8a-af5526e6c322","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[3,6536],"y":[2362,11091]}},"id":"a9ed641d-5df9-4b28-ac14-c61dcb6659e0","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Estimated Value"},"renderers":[{"id":"fe7a1b1a-8e60-408a-a925-07e4e0bbd227","type":"GlyphRenderer"}]},"id":"f7332b14-b512-4d7f-9a42-0e11a7c2e57f","type":"LegendItem"},{"attributes":{"plot":{"id":"03bec6cd-d67e-4a90-b929-356aff027e1c","subtype":"Figure","type":"Plot"}},"id":"a53d5cdc-e23b-46fa-8f37-a34dd83132d5","type":"ResetTool"},{"attributes":{"plot":{"id":"2b22b500-abf0-4a1f-ad75-f8ab02c ...

# %%
#Displaying the estimated values for column Detergents
show(row(figList[10:15]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="150728a1-ebfb-40b2-873e-5ea55a8cd5f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("150728a1-ebfb-40b2-873e-5ea55a8cd5f7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("150728a1-ebfb-40b2-873e-5ea55a8cd5f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '150728a1-ebfb-40b2-873e-5ea55a8cd5f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"67847aae-b2ee-4767-9c0a-5e8ce991abc3":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"17475d3e-36ab-484e-bacf-490842d01d55","type":"PanTool"},{"id":"b1f03bfc-d346-489a-8497-21995eb87567","type":"WheelZoomTool"},{"id":"c6df594a-a0d7-4e00-bea1-64953c409963","type":"BoxZoomTool"},{"id":"c019cd33-4f81-4320-8556-4fc155c80712","type":"SaveTool"},{"id":"256f7828-7471-4152-a901-b89ee651db0d","type":"ResetTool"},{"id":"2a925bf9-e456-44e9-9fa9-862ddf4e60e7","type":"HelpTool"}]},"id":"5e8e8639-dd7a-42c6-9a78-00edc917d086","type":"Toolbar"},{"attributes":{"plot":{"id":"dcfee574-acc8-4603-ac38-be742068c461","subtype":"Figure","type":"Plot"},"ticker":{"id":"a46bbb51-66b7-4bfe-9758-c19f23fc9851","type":"BasicTicker"}},"id":"38e6c687-4c98-4368-88e7-d2ea5dbd4c0a","type":"Grid"},{"attributes":{},"id":"9322188a-161a-4dd6-b1c8-0b9075dcc40b","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"f3cdf4b4-e052-46bb-948a-c10a937da131","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[761,523],"y":[761,523]}},"id":"f9150345-be90-4920-8a12-563d35b2fbb7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"822837ca-cac4-419e-aba8-632711d1da51","type":"Circle"},{"attributes":{"data_source":{"id":"1c743081-097e-4b98-a77d-d35e270b9736","type":"ColumnDataSource"},"glyph":{"id":"47b11b04-0ec9-4cd7-89c5-bb28c5b391c6","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a2871eb7-e3b8-468f-8216-203499e951f5","type":"Circle"},"selection_glyph":null},"id":"53b728f0-bd95-4777-8e4e-66fc2a567149","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2674,3293,3516,507,1777,1795,3140,3321,1716,7425,5977,549,3881,6707,5058,964,4508,370,2767,2518,2259,375,2381,4337,4482,4003,242,100,8604,1107,2134,820,918,361,483,4239,862,6506,6956,212,1145,2575,6899,9529,4618,7353,6792,24171,5121,13583,609,1538,2587,5611,204,2024,17740,7572,227,3084,4095,26701,4074,7677,1247,24231,3468,5141,788,656,116,4173,1321,764,1901,3,529,12034,301,1202,610,7818,3537,550,3837,40827,20070,1579,165,454,69,627,18906,71,5038,223,3874,54,56,215,8035,6766,4573,1480,1491,139,6830,8969,2505,836,169,6457,483,585,118,276,310,319,411,266,174,264,25,1976,500,778,349,2386,1062,410,395,70,955,256,47,199,2447,721,249,637,960,51,20,399,516,12591,73,1082,283,113,170,255,352,302,7,11577,6694,811,4004,8077,4424,3,232,13726,3674,7108,4973,1680,79,69,7015,8773,2840,9836,153,4196,1532,20,120,273,1382,4948,6907,239,334,58,949,3459,6839,4027,118,43,187,5618,355,330,763,4314,592,402,9959,14235,284,954,5,9265,288,5316,3381,12420,244,19410,240,3961,5957,5828,13308,130,4797,86,56,4167,256,788,70,761,2568,263,4762,694,955,1566,284,409,325,1216,415,28,72,828,343,412,586,1682,3143,8933,430,44,562,918,234,18594,205,363,1547,111,392,3593,730,967,780,49,429,2894,5980,830,4882,737,6374,333,197,147,93,210,759,96,603,621,274,3620,167,2328,1041,314,751,436,1226,386,445,32,965,212,825,5952,811,2208,710,3712,4538,290,2662,8752,6236,10069,11783,3909,7558,351,257,6846,299,371,17120,183,857,3891,83,821,706,12408,275,228,1470,1679,140,1272,387,88,210,492,182,9606,178,38102,332,4111,146,442,15,573,7271,5162,4595,15469,217,3843,6600,4621,1184,12218,173,12638,90,8682,1333,184,9,6747,536,232,468,159,179,1335,514,4515,222,252,101,41,523,716,397,1916,311,476,4666,96,68,813,600,246,1711,397,282,192,353,231,200,227,311,95,122,385,149,841,3378,64,74,469,153,92 ...

# %%
#Displaying the estimated values for column Delicassen
show(row(figList[15:20]))
